# %%
pip install -e git+https://github.com/dmnfarrell/pybioviz.git#egg=pybioviz
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Obtaining pybioviz from git+https://github.com/dmnfarrell/pybioviz.git#egg=pybioviz
#   Updating ./src/pybioviz clone
#   Running command git fetch -q --tags
#   Running command git reset --hard -q eef5e3812d59b23472d7ba8434b52841bf74fd6a
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: pybioviz
#     Found existing installation: pybioviz 0.1.0
#     Uninstalling pybioviz-0.1.0:
#       Successfully uninstalled pybioviz-0.1.0
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %%
import panel as pn
#need to load panel extension first
pn.extension()
from pybioviz import dashboards
app = dashboards.genome_features_viewer("crt-operon-from-Prokka.gff")
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [3], in <cell line: 5>()
#       3 pn.extension()
#       4 from pybioviz import dashboards
# ----> 5 app = dashboards.genome_features_viewer("KBase_derived_RD1_annnotation_Prokka.bam")
#
# File ~/Documents/Astaxanthin RD1 Project/python-scripts/src/pybioviz/pybioviz/dashboards.py:120, in genome_features_viewer(gff_file, ref_file, plot_width)
#     117 if gff_file is None:
#     118     return
# --> 120 features = utils.gff_to_features(gff_file)
#     121 df = utils.features_to_dataframe(features)
#     123 loc_pane = pnw.TextInput(name='location',value='',width=150)
#
# ...

# %%
app
# Out:
# Column(margin=20, sizing_mode='stretch_width', width_policy='max')
#     [0] Row
#         [0] TextInput(name='location', width=150)
#         [1] IntSlider(end=500, name='zoom', start=1, step=5, value=100, width=100)
#         [2] TextInput(name='find_gene', width=220)
#         [3] Select(name='chrom', width=220)
#         [4] Button(name='<', width=40)
#         [5] Button(name='>', width=40)
#     [1] IntSlider(end=5212, name='start', step=500, value=1, width=900)
#     [2] Column(sizing_mode='stretch_width')
#         [0] Bokeh(Figure, height=100, margin=10)
#         [1] Bokeh(None, height=50, margin=10)
#     [3] Str(str, style={'background': 'yellow', ...}, width=200)

# %%
app = dashboards.genome_features_viewer("KBase_derived_RD1_annnotation_Prokka.bam")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 app = dashboards.genome_features_viewer("KBase_derived_RD1_annnotation_Prokka.bam")
#
# File ~/Documents/Astaxanthin RD1 Project/python-scripts/src/pybioviz/pybioviz/dashboards.py:120, in genome_features_viewer(gff_file, ref_file, plot_width)
#     117 if gff_file is None:
#     118     return
# --> 120 features = utils.gff_to_features(gff_file)
#     121 df = utils.features_to_dataframe(features)
#     123 loc_pane = pnw.TextInput(name='location',value='',width=150)
#
# File ~/Documents/Astaxanthin RD1 Project/python-scripts/src/pybioviz/pybioviz/utils.py:242, in gff_to_features(gff_file)
#     240 from BCBio import GFF
#     241 in_handle = open(gff_file,'r')
# --> 242 rec = list(GFF.parse(in_handle))[0]
#     243 in_handle.close()
#     244 return rec.features
#
# ...
